# %%
import matplotlib.pyplot as plt

# %%
iris=load_iris()
x=iris.data
y=iris.target

# %%
from sklearn.datasets import load_iris

# %%
from sklearn.model_selection import train_test_split

# %%
from sklearn.neighbors import KNeighborsClassifier

# %%
from sklearn.metrics import accuracy_score

# %%
print("feature-x:")
print("x[:5]")
print("tur-y:")
print("y[:5]")
print("\ntür isimleri:")
print(iris.target_names)
# Out:
# feature-x:
# x[:5]
# tur-y:
# y[:5]
#
# tür isimleri:
# ['setosa' 'versicolor' 'virginica']

# %%
x_train,x_test,y_train,y_test = train_test_split(x,y,random_state=22,test_size=0.2)

# %%
print(f"\nEgitim Seti Boyutu (x_train):{x_train.shape}")
print(f"\nTest Seti Boyutu(x_test):{x_test.shape}")
# Out:
# Egitim Seti Boyutu (x_train):(120, 4)
#
# Test Seti Boyutu(x_test):(30, 4)

# %%
model=KNeighborsClassifier(n_neighbors=3)
model.fit(x_train,y_train)
print("\nModel Eğitildi")
# Out:
# Model Eğitildi

# %%
y_pred=model.predict(x_test)
accuracy=accuracy_score(y_test,y_pred)
print(f"\nModelin Doğruluğu(Accuracy)=%{accuracy*100:2f}")
# Out:
# Modelin Doğruluğu(Accuracy)=%96.666667

# %%
x_2d=x[:,:2]
x_train_2d,x_test_2d,y_train_2d,y_test_2d=train_test_split(x_2d, y, test_size=0.2,random_state=22)
model_2d=KNeighborsClassifier(n_neighbors=3)
model_2d.fit(x_train_2d,y_train_2d)
# Out:
# KNeighborsClassifier(n_neighbors=3)

# %%
plt.scatter(x_2d[:,0],x_2d[:,1], c=y, s=20,edgecolor='k',cmap=plt.cm.RdYlBu)
plt.xlabel(iris.feature_names[0])
plt.ylabel(iris.feature_names[1])
plt.title("iris çicek sınıf(K-NN)")
plt.show()

# %%
new_flower=[[5.0,3.5,1.4,0.2]]
predict_species=model.predict(new_flower)
print(f"\nYeni çiçek için tahmin edilen tür:{iris.target_names[predict_species[0]]}")
# Out:
# Yeni çiçek için tahmin edilen tür:setosa
